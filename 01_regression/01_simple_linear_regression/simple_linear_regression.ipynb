# %% [markdown]
# Import te libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Importing the dataset

# %%
dataset = pd.read_csv('Data.csv')
#print(dataset)
#independent variables
x = dataset.iloc[:, :-1].values
#dependent variables
y = dataset.iloc[:, -1].values

# %% [markdown]
# Split dataset into Training set and Testing set

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# Training Simple Linear Regression model

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train) #trains the model
# Out:
# LinearRegression()

# %% [markdown]
# Predicting the test set results

# %%
y_predict = regressor.predict(x_test)  #predicts Y based on X

# %% [markdown]
# Visualising the Training set result

# %%
plt.scatter(x_train, y_train, color='red')  #plots the salaries based on years of experience
plt.plot(x_train, regressor.predict(x_train), color='green')    #plots regression line
plt.title('Salary x Experience (Training set)')
plt.xlabel('Years of experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# Visualising the Test set result

# %%
plt.scatter(x_test, y_test, color='red')  #plots the salaries based on years of experience
plt.plot(x_train, regressor.predict(x_train), color='green')    #plots regression line
plt.title('Salary x Experience (Test set)')
plt.xlabel('Years of experience')
plt.ylabel('Salary')
plt.show()
